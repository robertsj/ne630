# %% [markdown]
# # NE 630 - Course Recap

# %% [markdown]
# ## Administrivia

# %% [markdown]
#  - all grades should be up to date (double check!)
#  - homework comments in pdf or comment box (depends on how you submitted)
#  - all solutions are posted

# %% [markdown]
# ## Final Exam
#
#   - is a take-home exam
#   - will be live at 1:40pm on Monday; due 1:40pm on Tuesday (24 hours)
#   - is to be a solo effort
#   - is to be 100% hand written; use of book, notes, homework solutions, Python, Wolfram Alpha, lucky coins, etc., are permitted; if in doubt, ask.  Scan and upload as a PDF.  Do not submit a .ipynb file.
#   - roughly same length; emphasis on post Exam-II material
#   - all three exams are equally weighted

# %% [markdown]
# ## TEVAL is live
#
# Constructive criticism is valuable (even though it can hurt)!
#
# I'm especially interested in *specific* examples of
#
#   - things that frustrated you (personal example: my math homework problem statements were often multiple pages---that was a lot of reading on top of regular assigned reading---and solutions were never provided)
#   - things that !frustrated (what's the right word for antifrustrate?) you (personal example: my first stats class showed me that the "line through noisy points" problem is an example of a much the much broader class of *linear models*: suddenly, everything I knew about matrices became 10x more relevant.)
#   - what could be emphasized or de-emphasized in *earlier* courses based on your experience in this and other senior-level courses

# %% [markdown]
# # Review
#
# Your problems/questions first!

# %% [markdown]
# ## Problem 1
#
# What is the probability that a neutron born *uniformly* in a homogeneous slab of width $a$ cm escapes the slab?  Assume that one-group diffusion theory is appropriate.  When is this appropriate?  How does the answer change with $D$?

# %% [markdown]
# ## Problem 2
#
# I used OpenMC to model a PWR unit cell with a fuel radius of 0.45 cm and a pitch of 1.5 cm.  From the simulation, I found these two-group data:
#
# ```
# region = fuel
# Σs11 = 0.3328
# Σs21 = 0.0008
# Σs22 = 0.3812
# Σa1 = 0.0313
# Σa2 = 0.3015
# region = non-fuel
# Σs11 = 0.2257
# Σs21 = 0.0266
# Σs22 = 1.0393
# Σa1 = 0.0003
# Σa2 = 0.0074
# fuel fission:
# Σf1 = 0.0095
# Σf2 = 0.2315
# Σf1 = 0.0095
# nu = 2.4398
# ```
#
# How would we model this unit cell using diffusion?
